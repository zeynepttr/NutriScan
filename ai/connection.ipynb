# %%
# !kaggle datasets download -d dietapp/turkish-food
# !unzip -q turkish-food.zip -d /content/
# Out:
# ...
# Dataset URL: https://www.kaggle.com/datasets/dietapp/turkish-food
# License(s): unknown
# ...
# 100% 1.24G/1.24G [01:12<00:00, 18.4MB/s]

# %%
# !kaggle datasets download -d kmader/food41
# !unzip -q food41.zip -d /content/
# Out:
# ...
# Dataset URL: https://www.kaggle.com/datasets/kmader/food41
# License(s): copyright-authors
# ...
# 100% 5.30G/5.30G [06:09<00:00, 15.4MB/s]

# %%
import os, shutil, random

source = "/content/Turkish Food"
base = "/content/turkish_food"

train_dir = base + "/train"
val_dir = base + "/val"

os.makedirs(train_dir, exist_ok=True)
os.makedirs(val_dir, exist_ok=True)

for cls in os.listdir(source):
    cls_path = os.path.join(source, cls)
    images = os.listdir(cls_path)
    random.shuffle(images)

    split = int(len(images)*0.8)

    for img in images[:split]:
        os.makedirs(os.path.join(train_dir, cls), exist_ok=True)
        shutil.copy(os.path.join(cls_path, img), os.path.join(train_dir, cls))

    for img in images[split:]:
        os.makedirs(os.path.join(val_dir, cls), exist_ok=True)
        shutil.copy(os.path.join(cls_path, img), os.path.join(val_dir, cls))
